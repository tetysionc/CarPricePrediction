# %%
ls '/content/drive/My Drive/Colab Notebooks/ML'
# Out:
# data/  HelloGIT.ipynb  LICENSE  PricesPrediction/  README.md

# %%
cd '/content/drive/My Drive/Colab Notebooks/ML/PricesPrediction/'
# Out:
# /content/drive/My Drive/Colab Notebooks/ML/PricesPrediction

# %%
#GITHUB_TOKEN = 'ba8ad306937be0eb0c756ed81979f5267ad62e64'
#GITHUB_URL = 'https://{0}@github.com/tetysionc/CarPricePrediction.git'.format(GITHUB_TOKEN)

# %%
# !git clone $GITHUB_URL
# Out:
# Cloning into 'CarPricePrediction'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 14 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (14/14), done.

# %%
ls
# Out:
# CarPricePrediction/  CarPricePrediction.ipynb  MaleShoesPricesPrediction.ipynb

# %%
# !mkdir data

# %%
import pandas as pd

# %%
df = pd.read_hdf('car.h5')
df.shape
# Out:
# (106494, 155)
